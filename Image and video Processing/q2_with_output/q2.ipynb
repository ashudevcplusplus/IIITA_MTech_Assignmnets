# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

imported_____image = cv2.imread("/content/Figure3.png",1);
imported_____image____HSV___conversion = cv2.cvtColor(imported_____image, cv2.COLOR_BGR2HSV)
      
# defining the range of masking
imported_____image_____blue1 = np.array([110, 50, 50])
imported_____image_____blue2 = np.array([130, 255, 255])
  
# initializing the imported_____image_____mask to be
# convoluted over input imported_____image
imported_____image_____mask = cv2.inRange(imported_____image____HSV___conversion, imported_____image_____blue1, imported_____image_____blue2)

# passing the bitwise_and over
# each pixel convoluted
imported_____image________final________output = cv2.bitwise_and(imported_____image, imported_____image, mask = imported_____image_____mask)
  
# defining the kernel______uesd___on____imported_____image i.e. Structuring element
kernel______uesd___on____imported_____image = np.ones((5, 5), np.uint8)
  
# defining the gradient____on_____imported_____image function 
# over the imported_____image and structuring element
gradient____on_____imported_____image = cv2.morphologyEx(imported_____image, cv2.MORPH_GRADIENT, kernel______uesd___on____imported_____image)
  
cv2_imshow(gradient____on_____imported_____image)
# Out:
# <PIL.Image.Image image mode=RGB size=936x718 at 0x7F66B7D0B850>
