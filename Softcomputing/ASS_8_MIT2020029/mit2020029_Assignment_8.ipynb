# %%
# -*- coding: utf-8 -*-
"""Untitled8.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/17NEJdDsR6zL_JoN6JpgPgm06NjeuePP_
"""

# Import Python Libraries
import numpy as numpy_imported_library

# Take two sets of patterns:
# Set A: Input Pattern
VARIABLE_X1 = numpy_imported_library.array([1, 1, 1, 1, 1, 1]).reshape(6, 1)
VARIABLE_X2 = numpy_imported_library.array([-1, -1, -1, -1, -1, -1]).reshape(6, 1)
VARIABLE_X3 = numpy_imported_library.array([1, -1, -1, 1, 1, 1]).reshape(6, 1)
VARIABLE_X4 = numpy_imported_library.array([1, 1, -1, -1, -1, -1]).reshape(6, 1)

# Set B: Target Pattern
VARIABLE_Y1 = numpy_imported_library.array([1, 1, 1]).reshape(3, 1)
VARIABLE_Y2 = numpy_imported_library.array([-1, -1, -1]).reshape(3, 1)
VARIABLE_Y3 = numpy_imported_library.array([-1, 1, 1]).reshape(3, 1)
VARIABLE_Y4 = numpy_imported_library.array([1, -1, 1]).reshape(3, 1)

'''
print("Set A: Input Pattern, Set B: Target Pattern")
print("\nThe input for pattern 1 is")
print(VARIABLE_X1)
print("\nThe target for pattern 1 is")
print(VARIABLE_Y1)
print("\nThe input for pattern 2 is")
print(VARIABLE_X2)
print("\nThe target for pattern 2 is")
print(VARIABLE_Y2)
print("\nThe input for pattern 3 is")
print(VARIABLE_X3)
print("\nThe target for pattern 3 is")
print(VARIABLE_Y3)
print("\nThe input for pattern 4 is")
print(VARIABLE_X4)
print("\nThe target for pattern 4 is")
print(VARIABLE_Y4)

print("\n------------------------------")
'''
# Calculate WIEGHT___________TRAINING Matrix: W
SET________________INPUTTED_X1_X2_X3_X4 = numpy_imported_library.concatenate((VARIABLE_X1, VARIABLE_X2, VARIABLE_X3, VARIABLE_X4), axis = 1)
SET_______________________TARGETTED = numpy_imported_library.concatenate((VARIABLE_Y1.T, VARIABLE_Y2.T, VARIABLE_Y3.T, VARIABLE_Y4.T), axis = 0)
print("\nWeight matrix:")
WIEGHT___________TRAINING = numpy_imported_library.dot(SET________________INPUTTED_X1_X2_X3_X4, SET_______________________TARGETTED)
print(WIEGHT___________TRAINING)

print("\n------------------------------")

# Testing Phase
# Test for Input Patterns: Set A
print("\nTesting for input patterns: Set A")
def testInputs(x, WIEGHT___________TRAINING):
# Multiply the input pattern with the WIEGHT___________TRAINING matrix
# (WIEGHT___________TRAINING.T X x)
 y = numpy_imported_library.dot(WIEGHT___________TRAINING.T, x)
 y[y < 0] = -1
 y[y >= 0] = 1
 return numpy_imported_library.array(y)
def accuracy(y,y_pred):
  c=0
  for i,j in zip(y,y_pred):
    if i==j:
      c=c+1
  return c   
print("\nOutput of input pattern 1")
print(testInputs(VARIABLE_X1, WIEGHT___________TRAINING))
ACCURACY_________________1=accuracy(VARIABLE_Y1,testInputs(VARIABLE_X1, WIEGHT___________TRAINING))
print("\nOutput of input pattern 2")
print(testInputs(VARIABLE_X2, WIEGHT___________TRAINING))
ACCURACY_________________2=accuracy(VARIABLE_Y2,testInputs(VARIABLE_X2, WIEGHT___________TRAINING))
print("\nOutput of input pattern 3")
print(testInputs(VARIABLE_X3, WIEGHT___________TRAINING))
ACCURACY_________________3=accuracy(VARIABLE_Y3,testInputs(VARIABLE_X3, WIEGHT___________TRAINING))
print("\nOutput of input pattern 4")
print(testInputs(VARIABLE_X4, WIEGHT___________TRAINING))
ACCURACY_________________4=accuracy(VARIABLE_Y4,testInputs(VARIABLE_X4, WIEGHT___________TRAINING))
TOTAL__________ACCURACY=ACCURACY_________________1+ACCURACY_________________2+ACCURACY_________________3+ACCURACY_________________4
TOTAL___________dENOMINATOR=12
print("accuracy:")
print(TOTAL__________ACCURACY/TOTAL___________dENOMINATOR)
# Test for Target Patterns: Set B
print("\nTesting for target patterns: Set B")
def testTargets(y, WIEGHT___________TRAINING):
# Multiply the target pattern with the WIEGHT___________TRAINING matrix
# (WIEGHT___________TRAINING X y)
 x = numpy_imported_library.dot(WIEGHT___________TRAINING, y)
 x[x <= 0] = -1
 x[x > 0] = 1
 return numpy_imported_library.array(x)

print("\nOutput of target pattern 1")
print(testTargets(VARIABLE_Y1, WIEGHT___________TRAINING))
print("\nOutput of target pattern 2")
print(testTargets(VARIABLE_Y2, WIEGHT___________TRAINING))
print("\nOutput of target pattern 3")
print(testTargets(VARIABLE_Y3, WIEGHT___________TRAINING))
print("\nOutput of target pattern 4")
print(testTargets(VARIABLE_Y4, WIEGHT___________TRAINING))

# Importing Libraries
import math
from tqdm.notebook import tqdm
import matplotlib.pyplot as plottinglibraryimport
import numpy as numpy_imported_library

# Generating Data : using uniform random number generator
variable________a_data_____from_imported = numpy_imported_library.random.uniform(-1, 1, (1500, 2))
# print(variable________a_data_____from_imported.shape)

# Hyperparameter Initialization
x, y = 10, 10     # dimensions of Map
HYPER______PARAM________SIGMA = 1.         # spread of neighborhood
HYPER______PARAM_________LR = 0.1 # learning rate
HYPER______PARAM_________EPOCHS = 100     # no of iterations
HPER_______PARAM_________DECAY__RATE_VARIABLE = HYPER______PARAM_________EPOCHS / 2 # decay parameter

# Activation map and Assigning Weights
# using random number generation
MAP___________VARIABLE______________ACTIVATION_____________FUNCTION = numpy_imported_library.zeros((x, y))
IMPORTED___________________________UPDATED____________TRAINED____WIEGHT = 2 * (numpy_imported_library.random.ranf((x, y, variable________a_data_____from_imported.shape[1])) - 0.5)
# print(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape)

# Define Neighborhood Region
neighbour_x = numpy_imported_library.arange(x)
neighbour_y = numpy_imported_library.arange(y)

# Function: DECAY________________METHOD___________LEARNING______RATE
def DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z):
 DECAY_________LEARNING____RATE_____VARIABLE = HYPER______PARAM_________LR/(1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)
 VAR___________SIGMA________HYPER_____PARAM = HYPER______PARAM________SIGMA / (1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)

 return DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM

# Function: to get winner neuron
def METHOD___________FETCH_______WINNER_____NEORON(x):
 s = numpy_imported_library.subtract(x, IMPORTED___________________________UPDATED____________TRAINED____WIEGHT) # x - w
 it = numpy_imported_library.nditer(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION, flags =['multi_index'])
 while not it.finished:
    # || x - w ||
     MAP___________VARIABLE______________ACTIVATION_____________FUNCTION[it.multi_index] = numpy_imported_library.linalg.norm(s[it.multi_index])
     it.iternext()

 return numpy_imported_library.unravel_index(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.argmin(), MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.shape)

# Update IMPORTED___________________________UPDATED____________TRAINED____WIEGHT
def METHOD__wieght_________updation_________fk_decay(win_neuron, inputx, TOTAL____________ITREATION_____Z):
# decay learning rate and HYPER______PARAM________SIGMA
 DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM = DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z)

# get neighborhood about winning neuron (Mexican hat function)
 d = 2 * numpy_imported_library.pi * (VAR___________SIGMA________HYPER_____PARAM**2)
 variable________ax_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_x - win_neuron[0]) / d)
 variable________ay_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_y - win_neuron[1]) / d)

 neighborhood = numpy_imported_library.outer(variable________ax_____from_imported, variable________ay_____from_imported)
 it = numpy_imported_library.nditer(neighborhood, flags = ['multi_index'])
 while not it.finished:
  IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index] += DECAY_________LEARNING____RATE_____VARIABLE * neighborhood[it.multi_index]* (inputx - IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index])
  it.iternext()

# Training model: Learning Phase
for ITR________DATASET____________EPOCHS__________COUNT in tqdm(range(1, HYPER______PARAM_________EPOCHS + 1)):
 numpy_imported_library.random.shuffle(variable________a_data_____from_imported)
 variable________idxxxx_____from_imported = numpy_imported_library.random.randint(0, variable________a_data_____from_imported.shape[0])
 win_neuron = METHOD___________FETCH_______WINNER_____NEORON(variable________a_data_____from_imported[variable________idxxxx_____from_imported])
 METHOD__wieght_________updation_________fk_decay(win_neuron, variable________a_data_____from_imported[variable________idxxxx_____from_imported], ITR________DATASET____________EPOCHS__________COUNT)

if ITR________DATASET____________EPOCHS__________COUNT == 100 or ITR________DATASET____________EPOCHS__________COUNT == 1000 or epoc == 10000 or ITR________DATASET____________EPOCHS__________COUNT == 20000 or ITR________DATASET____________EPOCHS__________COUNT == 30000 or ITR________DATASET____________EPOCHS__________COUNT == 40000:
    variable________ploting_x_____from_imported = []
    variable________ploting_y_____from_imported = []

    for i in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[0]):
      for j in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[1]):
          variable________ploting_x_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][0])
          variable________ploting_y_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][1])

    plottinglibraryimport.title('After ' + str(ITR________DATASET____________EPOCHS__________COUNT) + ' iterations')
    plottinglibraryimport.scatter(variable________ploting_x_____from_imported, variable________ploting_y_____from_imported, c = 'yellow')
    plottinglibraryimport.show()
    plottinglibraryimport.close()

# Importing Libraries
import math
from tqdm.notebook import tqdm
import matplotlib.pyplot as plottinglibraryimport
import numpy as numpy_imported_library

# Generating Data : using uniform random number generator
variable________a_data_____from_imported = numpy_imported_library.random.uniform(-1, 1, (1500, 2))
# print(variable________a_data_____from_imported.shape)

# Hyperparameter Initialization
x, y = 10, 10     # dimensions of Map
HYPER______PARAM________SIGMA = 1.         # spread of neighborhood
HYPER______PARAM_________LR = 0.1 # learning rate
HYPER______PARAM_________EPOCHS = 1000     # no of iterations
HPER_______PARAM_________DECAY__RATE_VARIABLE = HYPER______PARAM_________EPOCHS / 2 # decay parameter

# Activation map and Assigning Weights
# using random number generation
MAP___________VARIABLE______________ACTIVATION_____________FUNCTION = numpy_imported_library.zeros((x, y))
IMPORTED___________________________UPDATED____________TRAINED____WIEGHT = 2 * (numpy_imported_library.random.ranf((x, y, variable________a_data_____from_imported.shape[1])) - 0.5)
# print(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape)

# Define Neighborhood Region
neighbour_x = numpy_imported_library.arange(x)
neighbour_y = numpy_imported_library.arange(y)

# Function: DECAY________________METHOD___________LEARNING______RATE
def DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z):
 DECAY_________LEARNING____RATE_____VARIABLE = HYPER______PARAM_________LR/(1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)
 VAR___________SIGMA________HYPER_____PARAM = HYPER______PARAM________SIGMA / (1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)

 return DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM

# Function: to get winner neuron
def METHOD___________FETCH_______WINNER_____NEORON(x):
 s = numpy_imported_library.subtract(x, IMPORTED___________________________UPDATED____________TRAINED____WIEGHT) # x - w
 it = numpy_imported_library.nditer(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION, flags =['multi_index'])
 while not it.finished:
    # || x - w ||
     MAP___________VARIABLE______________ACTIVATION_____________FUNCTION[it.multi_index] = numpy_imported_library.linalg.norm(s[it.multi_index])
     it.iternext()

 return numpy_imported_library.unravel_index(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.argmin(), MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.shape)

# Update IMPORTED___________________________UPDATED____________TRAINED____WIEGHT
def METHOD__wieght_________updation_________fk_decay(win_neuron, inputx, TOTAL____________ITREATION_____Z):
# decay learning rate and HYPER______PARAM________SIGMA
 DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM = DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z)

# get neighborhood about winning neuron (Mexican hat function)
 d = 2 * numpy_imported_library.pi * (VAR___________SIGMA________HYPER_____PARAM**2)
 variable________ax_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_x - win_neuron[0]) / d)
 variable________ay_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_y - win_neuron[1]) / d)

 neighborhood = numpy_imported_library.outer(variable________ax_____from_imported, variable________ay_____from_imported)
 it = numpy_imported_library.nditer(neighborhood, flags = ['multi_index'])
 while not it.finished:
  IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index] += DECAY_________LEARNING____RATE_____VARIABLE * neighborhood[it.multi_index]* (inputx - IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index])
  it.iternext()

# Training model: Learning Phase
for ITR________DATASET____________EPOCHS__________COUNT in tqdm(range(1, HYPER______PARAM_________EPOCHS + 1)):
 numpy_imported_library.random.shuffle(variable________a_data_____from_imported)
 variable________idxxxx_____from_imported = numpy_imported_library.random.randint(0, variable________a_data_____from_imported.shape[0])
 win_neuron = METHOD___________FETCH_______WINNER_____NEORON(variable________a_data_____from_imported[variable________idxxxx_____from_imported])
 METHOD__wieght_________updation_________fk_decay(win_neuron, variable________a_data_____from_imported[variable________idxxxx_____from_imported], ITR________DATASET____________EPOCHS__________COUNT)

if ITR________DATASET____________EPOCHS__________COUNT == 100 or ITR________DATASET____________EPOCHS__________COUNT == 1000 or epoc == 10000 or ITR________DATASET____________EPOCHS__________COUNT == 20000 or ITR________DATASET____________EPOCHS__________COUNT == 30000 or ITR________DATASET____________EPOCHS__________COUNT == 40000:
    variable________ploting_x_____from_imported = []
    variable________ploting_y_____from_imported = []

    for i in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[0]):
      for j in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[1]):
          variable________ploting_x_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][0])
          variable________ploting_y_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][1])

    plottinglibraryimport.title('After ' + str(ITR________DATASET____________EPOCHS__________COUNT) + ' iterations')
    plottinglibraryimport.scatter(variable________ploting_x_____from_imported, variable________ploting_y_____from_imported, c = 'r')
    plottinglibraryimport.show()
    plottinglibraryimport.close()

# Importing Libraries
import math
from tqdm.notebook import tqdm
import matplotlib.pyplot as plottinglibraryimport
import numpy as numpy_imported_library

# Generating Data : using uniform random number generator
variable________a_data_____from_imported = numpy_imported_library.random.uniform(-1, 1, (1500, 2))
# print(variable________a_data_____from_imported.shape)

# Hyperparameter Initialization
x, y = 10, 10     # dimensions of Map
HYPER______PARAM________SIGMA = 1.         # spread of neighborhood
HYPER______PARAM_________LR = 0.1 # learning rate
HYPER______PARAM_________EPOCHS = 10000     # no of iterations
HPER_______PARAM_________DECAY__RATE_VARIABLE = HYPER______PARAM_________EPOCHS / 2 # decay parameter

# Activation map and Assigning Weights
# using random number generation
MAP___________VARIABLE______________ACTIVATION_____________FUNCTION = numpy_imported_library.zeros((x, y))
IMPORTED___________________________UPDATED____________TRAINED____WIEGHT = 2 * (numpy_imported_library.random.ranf((x, y, variable________a_data_____from_imported.shape[1])) - 0.5)
# print(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape)

# Define Neighborhood Region
neighbour_x = numpy_imported_library.arange(x)
neighbour_y = numpy_imported_library.arange(y)

# Function: DECAY________________METHOD___________LEARNING______RATE
def DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z):
 DECAY_________LEARNING____RATE_____VARIABLE = HYPER______PARAM_________LR/(1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)
 VAR___________SIGMA________HYPER_____PARAM = HYPER______PARAM________SIGMA / (1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)

 return DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM

# Function: to get winner neuron
def METHOD___________FETCH_______WINNER_____NEORON(x):
 
 s = numpy_imported_library.subtract(x, IMPORTED___________________________UPDATED____________TRAINED____WIEGHT) # x - w
 
 it = numpy_imported_library.nditer(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION, flags =['multi_index'])
 
 while not it.finished:
    # || x - w ||
     MAP___________VARIABLE______________ACTIVATION_____________FUNCTION[it.multi_index] = numpy_imported_library.linalg.norm(s[it.multi_index])
     it.iternext()

 return numpy_imported_library.unravel_index(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.argmin(), MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.shape)

# Update IMPORTED___________________________UPDATED____________TRAINED____WIEGHT
def METHOD__wieght_________updation_________fk_decay(win_neuron, inputx, TOTAL____________ITREATION_____Z):
# decay learning rate and HYPER______PARAM________SIGMA
 DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM = DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z)

# get neighborhood about winning neuron (Mexican hat function)
 d = 2 * numpy_imported_library.pi * (VAR___________SIGMA________HYPER_____PARAM**2)
 variable________ax_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_x - win_neuron[0]) / d)
 variable________ay_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_y - win_neuron[1]) / d)

 neighborhood = numpy_imported_library.outer(variable________ax_____from_imported, variable________ay_____from_imported)
 it = numpy_imported_library.nditer(neighborhood, flags = ['multi_index'])
 while not it.finished:
  IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index] += DECAY_________LEARNING____RATE_____VARIABLE * neighborhood[it.multi_index]* (inputx - IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index])
  it.iternext()

# Training model: Learning Phase
for ITR________DATASET____________EPOCHS__________COUNT in tqdm(range(1, HYPER______PARAM_________EPOCHS + 1)):
 numpy_imported_library.random.shuffle(variable________a_data_____from_imported)
 variable________idxxxx_____from_imported = numpy_imported_library.random.randint(0, variable________a_data_____from_imported.shape[0])
 win_neuron = METHOD___________FETCH_______WINNER_____NEORON(variable________a_data_____from_imported[variable________idxxxx_____from_imported])
 METHOD__wieght_________updation_________fk_decay(win_neuron, variable________a_data_____from_imported[variable________idxxxx_____from_imported], ITR________DATASET____________EPOCHS__________COUNT)

if ITR________DATASET____________EPOCHS__________COUNT == 100 or ITR________DATASET____________EPOCHS__________COUNT == 1000 or ITR________DATASET____________EPOCHS__________COUNT == 10000 or ITR________DATASET____________EPOCHS__________COUNT == 20000 or ITR________DATASET____________EPOCHS__________COUNT == 30000 or ITR________DATASET____________EPOCHS__________COUNT == 40000:
    variable________ploting_x_____from_imported = []
    variable________ploting_y_____from_imported = []

    for i in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[0]):
      for j in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[1]):
          variable________ploting_x_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][0])
          variable________ploting_y_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][1])

    plottinglibraryimport.title('After ' + str(ITR________DATASET____________EPOCHS__________COUNT) + ' iterations')
    plottinglibraryimport.scatter(variable________ploting_x_____from_imported, variable________ploting_y_____from_imported, c = 'pink')
    plottinglibraryimport.show()
    plottinglibraryimport.close()

# Importing Libraries
import math
from tqdm.notebook import tqdm
import matplotlib.pyplot as plottinglibraryimport
import numpy as numpy_imported_library

# Generating Data : using uniform random number generator
variable________a_data_____from_imported = numpy_imported_library.random.uniform(-1, 1, (1500, 2))
# print(variable________a_data_____from_imported.shape)

# Hyperparameter Initialization
x, y = 10, 10     # dimensions of Map
HYPER______PARAM________SIGMA = 1.         # spread of neighborhood
HYPER______PARAM_________LR = 0.1 # learning rate
HYPER______PARAM_________EPOCHS = 20000     # no of iterations
HPER_______PARAM_________DECAY__RATE_VARIABLE = HYPER______PARAM_________EPOCHS / 2 # decay parameter

# Activation map and Assigning Weights
# using random number generation
MAP___________VARIABLE______________ACTIVATION_____________FUNCTION = numpy_imported_library.zeros((x, y))
IMPORTED___________________________UPDATED____________TRAINED____WIEGHT = 2 * (numpy_imported_library.random.ranf((x, y, variable________a_data_____from_imported.shape[1])) - 0.5)
# print(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape)

# Define Neighborhood Region
neighbour_x = numpy_imported_library.arange(x)
neighbour_y = numpy_imported_library.arange(y)

# Function: DECAY________________METHOD___________LEARNING______RATE
def DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z):
 DECAY_________LEARNING____RATE_____VARIABLE = HYPER______PARAM_________LR/(1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)
 VAR___________SIGMA________HYPER_____PARAM = HYPER______PARAM________SIGMA / (1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)

 return DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM

# Function: to get winner neuron
def METHOD___________FETCH_______WINNER_____NEORON(x):
 s = numpy_imported_library.subtract(x, IMPORTED___________________________UPDATED____________TRAINED____WIEGHT) # x - w
 it = numpy_imported_library.nditer(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION, flags =['multi_index'])
 while not it.finished:
    # || x - w ||
     MAP___________VARIABLE______________ACTIVATION_____________FUNCTION[it.multi_index] = numpy_imported_library.linalg.norm(s[it.multi_index])
     it.iternext()

 return numpy_imported_library.unravel_index(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.argmin(), MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.shape)

# Update IMPORTED___________________________UPDATED____________TRAINED____WIEGHT
def METHOD__wieght_________updation_________fk_decay(win_neuron, inputx, TOTAL____________ITREATION_____Z):
# decay learning rate and HYPER______PARAM________SIGMA
 DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM = DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z)

# get neighborhood about winning neuron (Mexican hat function)
 d = 2 * numpy_imported_library.pi * (VAR___________SIGMA________HYPER_____PARAM**2)
 variable________ax_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_x - win_neuron[0]) / d)
 variable________ay_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_y - win_neuron[1]) / d)

 neighborhood = numpy_imported_library.outer(variable________ax_____from_imported, variable________ay_____from_imported)
 it = numpy_imported_library.nditer(neighborhood, flags = ['multi_index'])
 while not it.finished:
  IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index] += DECAY_________LEARNING____RATE_____VARIABLE * neighborhood[it.multi_index]* (inputx - IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index])
  it.iternext()

# Training model: Learning Phase
for ITR________DATASET____________EPOCHS__________COUNT in tqdm(range(1, HYPER______PARAM_________EPOCHS + 1)):
 numpy_imported_library.random.shuffle(variable________a_data_____from_imported)
 variable________idxxxx_____from_imported = numpy_imported_library.random.randint(0, variable________a_data_____from_imported.shape[0])
 win_neuron = METHOD___________FETCH_______WINNER_____NEORON(variable________a_data_____from_imported[variable________idxxxx_____from_imported])
 METHOD__wieght_________updation_________fk_decay(win_neuron, variable________a_data_____from_imported[variable________idxxxx_____from_imported], ITR________DATASET____________EPOCHS__________COUNT)

if ITR________DATASET____________EPOCHS__________COUNT == 100 or ITR________DATASET____________EPOCHS__________COUNT == 1000 or ITR________DATASET____________EPOCHS__________COUNT == 10000 or ITR________DATASET____________EPOCHS__________COUNT == 20000 or ITR________DATASET____________EPOCHS__________COUNT == 30000 or ITR________DATASET____________EPOCHS__________COUNT == 40000:
    variable________ploting_x_____from_imported = []
    variable________ploting_y_____from_imported = []

    for i in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[0]):
      for j in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[1]):
          variable________ploting_x_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][0])
          variable________ploting_y_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][1])

    plottinglibraryimport.title('After ' + str(ITR________DATASET____________EPOCHS__________COUNT) + ' iterations')
    plottinglibraryimport.scatter(variable________ploting_x_____from_imported, variable________ploting_y_____from_imported, c = 'orange')
    plottinglibraryimport.show()
    plottinglibraryimport.close()

# Importing Libraries
import math
from tqdm.notebook import tqdm
import matplotlib.pyplot as plottinglibraryimport
import numpy as numpy_imported_library

# Generating Data : using uniform random number generator
variable________a_data_____from_imported = numpy_imported_library.random.uniform(-1, 1, (1500, 2))
# print(variable________a_data_____from_imported.shape)

# Hyperparameter Initialization
x, y = 10, 10     # dimensions of Map
HYPER______PARAM________SIGMA = 1.         # spread of neighborhood
HYPER______PARAM_________LR = 0.1 # learning rate
HYPER______PARAM_________EPOCHS = 30000     # no of iterations
HPER_______PARAM_________DECAY__RATE_VARIABLE = HYPER______PARAM_________EPOCHS / 2 # decay parameter

# Activation map and Assigning Weights
# using random number generation
MAP___________VARIABLE______________ACTIVATION_____________FUNCTION = numpy_imported_library.zeros((x, y))
IMPORTED___________________________UPDATED____________TRAINED____WIEGHT = 2 * (numpy_imported_library.random.ranf((x, y, variable________a_data_____from_imported.shape[1])) - 0.5)
# print(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape)

# Define Neighborhood Region
neighbour_x = numpy_imported_library.arange(x)
neighbour_y = numpy_imported_library.arange(y)

# Function: DECAY________________METHOD___________LEARNING______RATE
def DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z):
 DECAY_________LEARNING____RATE_____VARIABLE = HYPER______PARAM_________LR/(1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)
 VAR___________SIGMA________HYPER_____PARAM = HYPER______PARAM________SIGMA / (1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)

 return DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM

# Function: to get winner neuron
def METHOD___________FETCH_______WINNER_____NEORON(x):
 s = numpy_imported_library.subtract(x, IMPORTED___________________________UPDATED____________TRAINED____WIEGHT) # x - w
 it = numpy_imported_library.nditer(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION, flags =['multi_index'])
 while not it.finished:
    # || x - w ||
     MAP___________VARIABLE______________ACTIVATION_____________FUNCTION[it.multi_index] = numpy_imported_library.linalg.norm(s[it.multi_index])
     it.iternext()

 return numpy_imported_library.unravel_index(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.argmin(), MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.shape)

# Update IMPORTED___________________________UPDATED____________TRAINED____WIEGHT
def METHOD__wieght_________updation_________fk_decay(win_neuron, inputx, TOTAL____________ITREATION_____Z):
# decay learning rate and HYPER______PARAM________SIGMA
 DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM = DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z)

# get neighborhood about winning neuron (Mexican hat function)
 d = 2 * numpy_imported_library.pi * (VAR___________SIGMA________HYPER_____PARAM**2)
 variable________ax_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_x - win_neuron[0]) / d)
 variable________ay_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_y - win_neuron[1]) / d)

 neighborhood = numpy_imported_library.outer(variable________ax_____from_imported, variable________ay_____from_imported)
 it = numpy_imported_library.nditer(neighborhood, flags = ['multi_index'])
 while not it.finished:
  IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index] += DECAY_________LEARNING____RATE_____VARIABLE * neighborhood[it.multi_index]* (inputx - IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index])
  it.iternext()

# Training model: Learning Phase
for ITR________DATASET____________EPOCHS__________COUNT in tqdm(range(1, HYPER______PARAM_________EPOCHS + 1)):
 numpy_imported_library.random.shuffle(variable________a_data_____from_imported)
 variable________idxxxx_____from_imported = numpy_imported_library.random.randint(0, variable________a_data_____from_imported.shape[0])
 win_neuron = METHOD___________FETCH_______WINNER_____NEORON(variable________a_data_____from_imported[variable________idxxxx_____from_imported])
 METHOD__wieght_________updation_________fk_decay(win_neuron, variable________a_data_____from_imported[variable________idxxxx_____from_imported], ITR________DATASET____________EPOCHS__________COUNT)

if ITR________DATASET____________EPOCHS__________COUNT == 100 or ITR________DATASET____________EPOCHS__________COUNT == 1000 or ITR________DATASET____________EPOCHS__________COUNT == 10000 or ITR________DATASET____________EPOCHS__________COUNT == 20000 or ITR________DATASET____________EPOCHS__________COUNT == 30000 or ITR________DATASET____________EPOCHS__________COUNT == 40000:
    variable________ploting_x_____from_imported = []
    variable________ploting_y_____from_imported = []

    for i in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[0]):
      for j in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[1]):
          variable________ploting_x_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][0])
          variable________ploting_y_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][1])

    plottinglibraryimport.title('After ' + str(ITR________DATASET____________EPOCHS__________COUNT) + ' iterations')
    plottinglibraryimport.scatter(variable________ploting_x_____from_imported, variable________ploting_y_____from_imported, c = 'brown')
    plottinglibraryimport.show()
    plottinglibraryimport.close()

# Importing Libraries
import math
from tqdm.notebook import tqdm
import matplotlib.pyplot as plottinglibraryimport
import numpy as numpy_imported_library

# Generating Data : using uniform random number generator
variable________a_data_____from_imported = numpy_imported_library.random.uniform(-1, 1, (1500, 2))
# print(variable________a_data_____from_imported.shape)

# Hyperparameter Initialization
x, y = 10, 10     # dimensions of Map
HYPER______PARAM________SIGMA = 1.         # spread of neighborhood
HYPER______PARAM_________LR = 0.1 # learning rate
HYPER______PARAM_________EPOCHS = 40000     # no of iterations
HPER_______PARAM_________DECAY__RATE_VARIABLE = HYPER______PARAM_________EPOCHS / 2 # decay parameter

# Activation map and Assigning Weights
# using random number generation
MAP___________VARIABLE______________ACTIVATION_____________FUNCTION = numpy_imported_library.zeros((x, y))
IMPORTED___________________________UPDATED____________TRAINED____WIEGHT = 2 * (numpy_imported_library.random.ranf((x, y, variable________a_data_____from_imported.shape[1])) - 0.5)
# print(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape)

# Define Neighborhood Region
neighbour_x = numpy_imported_library.arange(x)
neighbour_y = numpy_imported_library.arange(y)

# Function: DECAY________________METHOD___________LEARNING______RATE
def DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z):
 DECAY_________LEARNING____RATE_____VARIABLE = HYPER______PARAM_________LR/(1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)
 VAR___________SIGMA________HYPER_____PARAM = HYPER______PARAM________SIGMA / (1 + TOTAL____________ITREATION_____Z / HPER_______PARAM_________DECAY__RATE_VARIABLE)

 return DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM

# Function: to get winner neuron
def METHOD___________FETCH_______WINNER_____NEORON(x):
 s = numpy_imported_library.subtract(x, IMPORTED___________________________UPDATED____________TRAINED____WIEGHT) # x - w
 it = numpy_imported_library.nditer(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION, flags =['multi_index'])
 while not it.finished:
    # || x - w ||
     MAP___________VARIABLE______________ACTIVATION_____________FUNCTION[it.multi_index] = numpy_imported_library.linalg.norm(s[it.multi_index])
     it.iternext()

 return numpy_imported_library.unravel_index(MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.argmin(), MAP___________VARIABLE______________ACTIVATION_____________FUNCTION.shape)

# Update IMPORTED___________________________UPDATED____________TRAINED____WIEGHT
def METHOD__wieght_________updation_________fk_decay(win_neuron, inputx, TOTAL____________ITREATION_____Z):
# decay learning rate and HYPER______PARAM________SIGMA
 DECAY_________LEARNING____RATE_____VARIABLE, VAR___________SIGMA________HYPER_____PARAM = DECAY________________METHOD___________LEARNING______RATE(TOTAL____________ITREATION_____Z)

# get neighborhood about winning neuron (Mexican hat function)
 d = 2 * numpy_imported_library.pi * (VAR___________SIGMA________HYPER_____PARAM**2)
 variable________ax_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_x - win_neuron[0]) / d)
 variable________ay_____from_imported = numpy_imported_library.exp(-1 * numpy_imported_library.square(neighbour_y - win_neuron[1]) / d)

 neighborhood = numpy_imported_library.outer(variable________ax_____from_imported, variable________ay_____from_imported)
 it = numpy_imported_library.nditer(neighborhood, flags = ['multi_index'])
 while not it.finished:
  IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index] += DECAY_________LEARNING____RATE_____VARIABLE * neighborhood[it.multi_index]* (inputx - IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[it.multi_index])
  it.iternext()

# Training model: Learning Phase
for ITR________DATASET____________EPOCHS__________COUNT in tqdm(range(1, HYPER______PARAM_________EPOCHS + 1)):
 numpy_imported_library.random.shuffle(variable________a_data_____from_imported)
 variable________idxxxx_____from_imported = numpy_imported_library.random.randint(0, variable________a_data_____from_imported.shape[0])
 win_neuron = METHOD___________FETCH_______WINNER_____NEORON(variable________a_data_____from_imported[variable________idxxxx_____from_imported])
 METHOD__wieght_________updation_________fk_decay(win_neuron, variable________a_data_____from_imported[variable________idxxxx_____from_imported], ITR________DATASET____________EPOCHS__________COUNT)

if ITR________DATASET____________EPOCHS__________COUNT == 100 or ITR________DATASET____________EPOCHS__________COUNT == 1000 or ITR________DATASET____________EPOCHS__________COUNT == 10000 or ITR________DATASET____________EPOCHS__________COUNT == 20000 or ITR________DATASET____________EPOCHS__________COUNT == 30000 or ITR________DATASET____________EPOCHS__________COUNT == 40000:
    variable________ploting_x_____from_imported = []
    variable________ploting_y_____from_imported = []

    for i in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[0]):
      for j in range(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT.shape[1]):
          variable________ploting_x_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][0])
          variable________ploting_y_____from_imported.append(IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[i][j][1])

    plottinglibraryimport.title('After ' + str(ITR________DATASET____________EPOCHS__________COUNT) + ' iterations')
    plottinglibraryimport.scatter(variable________ploting_x_____from_imported, variable________ploting_y_____from_imported, c = 'magenta')
    plottinglibraryimport.show()
    plottinglibraryimport.close()

# Testing the model performance
test_inputs = numpy_imported_library.array([[0.1, 0.8], [0.5, -0.2], [-0.8, -0.9], [-0.6, 0.9]])
# print(test_inputs.shape)

# The plots below depict the working of this Kohonen Network on
# given test inputs [0.1, 0.8], [0.5, -0.2], [-0.8, -0.9], [-0.6, 0.9]
for i in range(test_inputs.shape[0]):
 test_input = test_inputs[i, :]
 win_neuron = METHOD___________FETCH_______WINNER_____NEORON(test_input)

 variable________ploting_x_____from_imported = numpy_imported_library.arange(-1, 1, 0.1)
 variable________ploting_y_____from_imported = numpy_imported_library.arange(-1, 1, 0.1)
 xxxxxxxxxxxxxxxxxxxx, yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy = numpy_imported_library.meshgrid(variable________ploting_x_____from_imported, variable________ploting_y_____from_imported)

 variable__x______co_ordinates, variable__y______co_ordinates = IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[win_neuron[0]][win_neuron[1]][0],IMPORTED___________________________UPDATED____________TRAINED____WIEGHT[win_neuron[0]][win_neuron[1]][1]
 dist = math.sqrt((variable__x______co_ordinates-test_input[0])**2 + (variable__y______co_ordinates - test_input[1])**2)
 variable__x______co_ordinates = round(variable__x______co_ordinates, 1)
 variable__y______co_ordinates = round(variable__y______co_ordinates, 1)

 plottinglibraryimport.figure(figsize =(5, 8))
 plottinglibraryimport.title("Distance between activated neuron and input = " + str(dist), fontsize = 13)
 plottinglibraryimport.scatter(xxxxxxxxxxxxxxxxxxxx, yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy, c = 'pink')
 plottinglibraryimport.scatter(variable__x______co_ordinates, variable__y______co_ordinates, c = 'black')
 plottinglibraryimport.show()
 plottinglibraryimport.close()
# Out:
# Weight matrix:
# [[2 2 4]
#  [4 0 2]
#  [2 2 0]
#  [0 4 2]
#  [0 4 2]
#  [0 4 2]]
#
# ------------------------------
#
# Testing for input patterns: Set A
#
# Output of input pattern 1
# [[1]
#  [1]
#  [1]]
#
# Output of input pattern 2
# [[-1]
#  [-1]
#  [-1]]
#
# Output of input pattern 3
# [[-1]
#  [ 1]
#  [ 1]]
#
# Output of input pattern 4
# [[ 1]
#  [-1]
#  [ 1]]
# accuracy:
# 1.0
#
# Testing for target patterns: Set B
#
# Output of target pattern 1
# [[1]
#  [1]
#  [1]
#  [1]
#  [1]
#  [1]]
#
# Output of target pattern 2
# [[-1]
#  [-1]
#  [-1]
#  [-1]
#  [-1]
#  [-1]]
#
# Output of target pattern 3
# [[ 1]
#  [-1]
#  [-1]
#  [ 1]
#  [ 1]
#  [ 1]]
#
# Output of target pattern 4
# [[ 1]
#  [ 1]
#  [-1]
#  [-1]
#  [-1]
#  [-1]]
# ...
